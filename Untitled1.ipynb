# %% [markdown]
# ## 17(b) rainfall

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rain=pd.read_csv('district wise rainfall normal.csv')
rain
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
rain.groupby('DISTRICT')['ANNUAL'].max()
# Out:
# DISTRICT
# ADILABAD       1120.0
# AGRA            774.6
# AHMEDABAD       639.9
# AHMEDNAGAR      573.2
# AIZAWL         2814.4
#                 ...
# YADGIR          834.5
# YAMUNANAGAR    1107.0
# YANAM          1336.5
# YAVATMAL        982.8
# ZUNHEBOTO      2080.0
# Name: ANNUAL, Length: 637, dtype: float64

# %%
sort=rain.sort_values(by='ANNUAL',ascending=False)
sort
# Out:
#          STATE_UT_NAME       DISTRICT   JAN    FEB    MAR    APR    MAY  \
# 55             MANIPUR     TAMENGLONG  48.5  229.6  224.5  431.5  539.9
# 47           MEGHALAYA  JAINTIA HILLS  33.8   44.1  115.1  282.3  598.8
# 46           MEGHALAYA  EAST KHASI HI  15.4   24.1  129.7  312.5  733.7
# 12   ARUNACHAL PRADESH    UPPER SIANG  74.3  176.7  362.6  397.5  408.7
# 598          KARNATAKA          UDUPI   1.4    0.4    4.1   29.4  193.8
# ..                 ...            ...   ...    ...    ...    ...    ...
# 370          RAJASTHAN         BARMER   1.2    1.7    2.3    3.2    9.1
# 373          RAJASTHAN  SRI GANGANAGA   6.0    8.0    9.3    7.0   11.6
# 359  JAMMU AND KASHMIR         KARGIL  25.6   25.6   25.1   19.7   22.0
# 374          RAJASTHAN      JAISALMER   1.7    2.9    2.2    3.8    6.6
# 353  JAMMU AND KASHMIR   LADAKH (LEH)   8.1    7.3    8.8    8.0    8.0
#
#         JUN     JUL     AUG    SEP    OCT    NOV   DEC  ANNUAL  Jan-Feb  \
# ...

# %%
highest=sort.iloc[0,1]
highest
# Out:
# 'TAMENGLONG'

# %%
new_rain=rain.drop(['Jan-Feb','Mar-May','Jun-Sep','Oct-Dec'],axis=1)
new_rain
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
new_rain=new_rain.drop(['ANNUAL'],axis=1)
new_rain
new_rain.pivot_table(index='STATE_UT_NAME')
# Out:
# C:\Users\NEW\AppData\Local\Temp\ipykernel_9176\1438315106.py:3: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   new_rain.pivot_table(index='STATE_UT_NAME')
#                                     APR         AUG         DEC        FEB  \
# STATE_UT_NAME
# ANDAMAN And NICOBAR ISLANDS   86.966667  385.300000  159.733333  33.266667
# ANDHRA PRADESH                19.873913  179.426087   15.565217   7.352174
# ARUNACHAL PRADESH            275.162500  378.600000   35.956250  93.293750
# ASSAM                        181.266667  377.370370   11.440741  31.714815
# BIHAR                         16.865789  289.481579    5.786842   9.278947
# CHANDIGARH                    14.800000  287.500000   23.400000  38.900000
# CHATISGARH                    13.116667  375.338889    5.811111  10.472222
# ...

# %% [markdown]
# ## 17(a)

# %%
cars=pd.read_csv('mtcars.csv')
cars.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
plt.hist(cars['mpg'],rwidth=0.9)
plt.title('Frequency distribution of MPG')
plt.xlabel('MPG')
plt.ylabel('Frequency')
plt.show()

interval=cars['mpg'].value_counts().idxmax()
interval
# Out:
# 21.0

# %%
plt.scatter(cars['wt'],cars['mpg'])
plt.xlabel('weight')
plt.ylabel('mpg')
plt.grid()
plt.show()

# %%
plt.bar(cars['am'],height=0.8,width=0.2)
plt.xlabel('Transmission type')
plt.ylabel('frequency')
plt.title('Frequency distribution of transmission type')
plt.show()

# %%
plt.boxplot(cars['mpg'])
plt.show()
print("The five number summary:")
cars['mpg'].describe()
# Out:
# The five number summary:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %% [markdown]
# ## 16(a)

# %%
list_1=[1,2,3,4,5]
print(list_1)
sq_list=[]
sq_list=list(map(lambda x:x**2,list_1))
print(sq_list)
# Out:
# [1, 2, 3, 4, 5]
# [1, 4, 9, 16, 25]

# %%
oddl=list(filter(lambda x:True if (x%2!=0) else False ,list_1))
oddl
# Out:
# [1, 3, 5]

# %%
from functools import reduce
l=np.arange(6)
print(l)
sum=(reduce(lambda a,b:a+b,l))
sum
# Out:
# [0 1 2 3 4 5]
# 15

# %% [markdown]
# ## 12

# %%
emp=pd.read_csv('empdata.csv')
emp
# Out:
#   First Name Last Name                Type      Department  YoE  Salary
# 0      Aryan     Singh  Full-time Employee  Administration    2   20000
# 1      Rohan   Agarwal              Intern       Technical    3    5000
# 2       Riya      Shah  Full-time Employee  Administration    5   10000
# 3       Yash    Bhatia  Part-time Employee       Technical    7   10000
# 4   Siddhant    Khanna  Full-time Employee      Management    6   20000

# %%
emp.pivot_table(index='Department',columns='Type',values='Salary')
# Out:
# Type            Full-time Employee  Intern  Part-time Employee
# Department
# Administration             15000.0     NaN                 NaN
# Management                 20000.0     NaN                 NaN
# Technical                      NaN  5000.0             10000.0

# %%
emp.pivot_table(index='Type',values='Salary',aggfunc=['sum','mean','count'])
# Out:
#                       sum          mean  count
#                    Salary        Salary Salary
# Type
# Full-time Employee  50000  16666.666667      3
# Intern               5000   5000.000000      1
# Part-time Employee  10000  10000.000000      1

# %%
emp.pivot_table(index='Type',values='Salary',aggfunc='std')
# Out:
#                          Salary
# Type
# Full-time Employee  5773.502692

# %% [markdown]
# ## 11

# %%
books=pd.read_csv('books.csv')
books
# Out:
#    Number  Pencil  TextBooks  Drawing Sheets  Total Units  Profits
# 0       1     300        250             100          800     8000
# 1       2     350        350             200         1000     9500
# 2       3     400        400             200         1320    10256
# 3       4     500        420             250         1510    12000
# 4       5     520        500             300         2000    18000

# %%
books.describe()
# Out:
#          Number      Pencil   TextBooks  Drawing Sheets  Total Units  \
# count  5.000000    5.000000    5.000000        5.000000     5.000000
# mean   3.000000  414.000000  384.000000      210.000000  1326.000000
# std    1.581139   94.762862   92.357999       74.161985   466.669048
# min    1.000000  300.000000  250.000000      100.000000   800.000000
# 25%    2.000000  350.000000  350.000000      200.000000  1000.000000
# 50%    3.000000  400.000000  400.000000      200.000000  1320.000000
# 75%    4.000000  500.000000  420.000000      250.000000  1510.000000
# max    5.000000  520.000000  500.000000      300.000000  2000.000000
#
#             Profits
# count      5.000000
# mean   11551.200000
# std     3882.152393
# min     8000.000000
# 25%     9500.000000
# 50%    10256.000000
# 75%    12000.000000
# max    18000.000000

# %%
plt.plot(books['Number'],books['Profits'],marker='o')
plt.title('Showing Total profits')
plt.xlabel('Numbers')
plt.ylabel('Profits')
plt.grid(True)
plt.show()

# %%
books.isnull().sum()
# Out:
# Number            0
# Pencil            0
# TextBooks         0
# Drawing Sheets    0
# Total Units       0
# Profits           0
# dtype: int64

# %%
books['Profits'].sum()
# Out:
# 57756

# %%
books['Drawing Sheets'].max()
# Out:
# 300

# %% [markdown]
# ## 10(a)

# %%
iris=pd.read_csv('iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.shape
# Out:
# (150, 6)

# %%
plt.scatter(iris['PetalLengthCm'],iris['PetalWidthCm'],marker='*')
plt.xlabel('PetalLengthCm')
plt.ylabel('PetalWidthCm')
plt.grid()
plt.show()

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ## 9

# %%
Series_A=pd.Series([10, 20, 30, 40, 50])
Series_B =pd.Series([40, 50, 60, 70, 80])
print(Series_A)
print(Series_B)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 0    40
# 1    50
# 2    60
# 3    70
# 4    80
# dtype: int64

# %%
u=pd.Series(np.union1d(Series_A,Series_B))
i=pd.Series(np.intersect1d(Series_A,Series_B))
not_com=u[~u.isin(i)]
not_com
# Out:
# 0    10
# 1    20
# 2    30
# 5    60
# 6    70
# 7    80
# dtype: int64

# %%
maxA=Series_A.max()
minA=Series_A.min()
print(f"The maximum value={maxA}")
print(f"The minimum value={minA}")
# Out:
# The maximum value=50
# The minimum value=10

# %%
sumB=Series_B.sum()
print(f"The sum of Series_B= {sumB}")
# Out:
# The sum of Series_B= 300

# %%
midB=Series_B.median()
print(f"The median of Series_B= {midB}")
# Out:
# The median of Series_B= 60.0

# %% [markdown]
# ## 8

# %%
car=pd.read_csv('auto-mpg.csv')
car.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
car
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
car[car['cylinders']==8]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 291  19.2          8         267.0        125    3605          15.0
# 292  18.5          8         360.0        150    3940          13.0
# 298  23.0          8         350.0        125    3900          17.4
# 300  23.9          8         260.0         90    3420          22.2
# 364  26.6          8         350.0        105    3725          19.0
#
#      model year  origin                              car name
# 0            70       1             chevrolet chevelle malibu
# ...

# %%
car.groupby('model year')['car name'].count()
# Out:
# model year
# 70    29
# 71    28
# 72    28
# 73    40
# 74    27
# 75    30
# 76    34
# 77    28
# 78    36
# 79    29
# 80    29
# 81    29
# 82    31
# Name: car name, dtype: int64
